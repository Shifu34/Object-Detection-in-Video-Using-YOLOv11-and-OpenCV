# %%
pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.35-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.8.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.12-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.35-py3-none-any.whl (887 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.4/887.4 kB 16.8 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.12-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.35 ultralytics-thop-2.0.12

# %%
import torch
import cv2
from ultralytics import YOLO

# Load the YOLO model (change to YOLOv11 when available)
model = YOLO("yolo11n.pt")

# Initialize video capture
video_input = 'Example.mp4'  # Path to input video
video_output = 'output_video.mp4'  # Path to save output video
cap = cv2.VideoCapture(video_input)

# Get video properties
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

# Define the codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter(video_output, fourcc, fps, (width, height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Detect objects in the frame
    results = model(frame)

    # Draw boxes on the frame
    for result in results:
        boxes = result.boxes  # Get detected boxes
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0]  # Bounding box coordinates
            conf = box.conf[0]  # Confidence score
            cls = int(box.cls[0])  # Class ID
            label = f'{model.names[cls]} {conf:.2f}'  # Get class name and confidence

            # Draw rectangle and label
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (255, 0, 0), 2)
            cv2.putText(frame, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

    # Write the processed frame to the output video
    out.write(frame)

# Release resources
cap.release()
out.release()
# Out:
# 0: 320x640 1 person, 12.0ms
# Speed: 1.5ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 tie, 15.2ms
# Speed: 1.7ms preprocess, 15.2ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 tie, 9.6ms
# Speed: 2.6ms preprocess, 9.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 tie, 8.8ms
# Speed: 1.3ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 tie, 9.9ms
# Speed: 2.3ms preprocess, 9.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 tie, 9.2ms
# Speed: 2.1ms preprocess, 9.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 tie, 10.8ms
# Speed: 1.7ms preprocess, 10.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 tie, 10.0ms
# Speed: 1.7ms preprocess, 10.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 tie, 9.3ms
# Speed: 2.1ms preprocess, 9.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13.3ms
# Speed: 1.6ms preprocess, 13.3ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.0ms
# Speed: 1.8ms preprocess, 15.0ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14.3ms
# Speed: 3.9ms preprocess, 14.3ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.6ms
# Speed: 1.8ms preprocess, 15.6ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.6ms
# Speed: 1.7ms preprocess, 17.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.5ms
# Speed: 1.7ms preprocess, 16.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13.7ms
# Speed: 1.8ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 13.4ms
# Speed: 1.7ms preprocess, 13.4ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 18.8ms
# Speed: 1.8ms preprocess, 18.8ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 17.3ms
# Speed: 1.7ms preprocess, 17.3ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 14.6ms
# Speed: 3.3ms preprocess, 14.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.8ms
# Speed: 2.7ms preprocess, 15.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12.1ms
# Speed: 1.7ms preprocess, 12.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12.0ms
# Speed: 1.6ms preprocess, 12.0ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13.8ms
# Speed: 2.0ms preprocess, 13.8ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.7ms
# Speed: 1.7ms preprocess, 19.7ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.0ms
# Speed: 2.9ms preprocess, 16.0ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.0ms
# Speed: 2.3ms preprocess, 16.0ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.2ms
# Speed: 1.9ms preprocess, 15.2ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.6ms
# Speed: 1.6ms preprocess, 19.6ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12.6ms
# Speed: 4.2ms preprocess, 12.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.3ms
# Speed: 3.9ms preprocess, 16.3ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tie, 19.9ms
# Speed: 2.3ms preprocess, 19.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13.5ms
# Speed: 2.8ms preprocess, 13.5ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 ties, 15.4ms
# Speed: 3.2ms preprocess, 15.4ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.1ms
# Speed: 1.6ms preprocess, 15.1ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.9ms
# Speed: 1.6ms preprocess, 18.9ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13.9ms
# Speed: 1.9ms preprocess, 13.9ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 24.6ms
# Speed: 1.6ms preprocess, 24.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14.4ms
# Speed: 1.9ms preprocess, 14.4ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14.7ms
# Speed: 1.7ms preprocess, 14.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.6ms
# Speed: 1.8ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13.7ms
# Speed: 2.4ms preprocess, 13.7ms inference, 3.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.9ms
# Speed: 3.3ms preprocess, 16.9ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14.8ms
# Speed: 1.7ms preprocess, 14.8ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tie, 16.0ms
# Speed: 1.7ms preprocess, 16.0ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tie, 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.6ms
# Speed: 1.6ms preprocess, 16.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14.5ms
# Speed: 4.2ms preprocess, 14.5ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 13.8ms
# Speed: 3.9ms preprocess, 13.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.8ms
# Speed: 1.7ms preprocess, 18.8ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.8ms
# Speed: 3.0ms preprocess, 17.8ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.0ms
# Speed: 2.0ms preprocess, 23.0ms inference, 4.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.4ms
# Speed: 1.7ms preprocess, 23.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.5ms
# Speed: 4.0ms preprocess, 23.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.3ms
# Speed: 1.7ms preprocess, 19.3ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 21.2ms
# Speed: 1.8ms preprocess, 21.2ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.1ms
# Speed: 1.9ms preprocess, 17.1ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.1ms
# Speed: 1.7ms preprocess, 15.1ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 21.0ms
# Speed: 2.1ms preprocess, 21.0ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.8ms
# Speed: 1.9ms preprocess, 19.8ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.1ms
# Speed: 1.7ms preprocess, 16.1ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 14.4ms
# Speed: 1.8ms preprocess, 14.4ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 15.9ms
# Speed: 1.7ms preprocess, 15.9ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 20.0ms
# Speed: 2.7ms preprocess, 20.0ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.5ms
# Speed: 3.2ms preprocess, 19.5ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 17.8ms
# Speed: 4.4ms preprocess, 17.8ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 29.4ms
# Speed: 2.6ms preprocess, 29.4ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 24.2ms
# Speed: 1.8ms preprocess, 24.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 19.9ms
# Speed: 1.7ms preprocess, 19.9ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.3ms
# Speed: 1.7ms preprocess, 16.3ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 cell phone, 18.9ms
# Speed: 1.9ms preprocess, 18.9ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 cell phone, 20.2ms
# Speed: 1.7ms preprocess, 20.2ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 cell phone, 27.7ms
# Speed: 3.6ms preprocess, 27.7ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 cell phone, 19.7ms
# Speed: 2.5ms preprocess, 19.7ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 cell phone, 16.8ms
# Speed: 1.7ms preprocess, 16.8ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 cell phone, 16.6ms
# Speed: 1.7ms preprocess, 16.6ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 cell phone, 16.5ms
# Speed: 1.7ms preprocess, 16.5ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 cell phone, 18.5ms
# Speed: 1.6ms preprocess, 18.5ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 2 cell phones, 18.8ms
# Speed: 1.7ms preprocess, 18.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.1ms
# Speed: 1.9ms preprocess, 18.1ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.4ms
# Speed: 2.1ms preprocess, 16.4ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 18.7ms
# Speed: 1.6ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 cell phone, 16.5ms
# Speed: 1.8ms preprocess, 16.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 16.1ms
# Speed: 4.2ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 cell phone, 14.8ms
# Speed: 1.8ms preprocess, 14.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cell phones, 9.5ms
# Speed: 1.5ms preprocess, 9.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cell phones, 10.1ms
# Speed: 1.7ms preprocess, 10.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 3 cell phones, 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 cell phone, 10.2ms
# Speed: 1.7ms preprocess, 10.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 cell phone, 10.2ms
# Speed: 1.7ms preprocess, 10.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9.9ms
# Speed: 1.6ms preprocess, 9.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 cell phone, 9.9ms
# Speed: 1.8ms preprocess, 9.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 cell phone, 10.0ms
# Speed: 1.6ms preprocess, 10.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 10.0ms
# Speed: 1.5ms preprocess, 10.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 23.1ms
# Speed: 1.8ms preprocess, 23.1ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11.8ms
# Speed: 1.7ms preprocess, 11.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 12.9ms
# Speed: 1.6ms preprocess, 12.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9.9ms
# Speed: 2.1ms preprocess, 9.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9.9ms
# Speed: 3.2ms preprocess, 9.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11.0ms
# Speed: 1.6ms preprocess, 11.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 9.1ms
# Speed: 1.6ms preprocess, 9.1ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 11.1ms
# Speed: 1.9ms preprocess, 11.1ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 tv, 10.9ms
# Speed: 1.9ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 person, 1 tv, 10.7ms
# Speed: 1.7ms preprocess, 10.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 16.0ms
# Speed: 1.7ms preprocess, 16.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 9.5ms
# Speed: 1.7ms preprocess, 9.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 1 tv, 10.8ms
# Speed: 1.8ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 13.1ms
# Speed: 1.8ms preprocess, 13.1ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 10.7ms
# Speed: 1.7ms preprocess, 10.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 10.6ms
# Speed: 1.7ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 12.6ms
# Speed: 2.4ms preprocess, 12.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 12.6ms
# Speed: 1.6ms preprocess, 12.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 13.5ms
# Speed: 1.6ms preprocess, 13.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 13.1ms
# Speed: 1.6ms preprocess, 13.1ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 17.3ms
# Speed: 1.6ms preprocess, 17.3ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 12.0ms
# Speed: 3.8ms preprocess, 12.0ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 14.6ms
# Speed: 1.7ms preprocess, 14.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 13.5ms
# Speed: 2.4ms preprocess, 13.5ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 12.6ms
# Speed: 1.6ms preprocess, 12.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 15.1ms
# Speed: 1.6ms preprocess, 15.1ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 13.8ms
# Speed: 1.6ms preprocess, 13.8ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 13.9ms
# Speed: 1.7ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 14.0ms
# Speed: 2.4ms preprocess, 14.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 12.6ms
# Speed: 2.0ms preprocess, 12.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 12.4ms
# Speed: 1.7ms preprocess, 12.4ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 14.7ms
# Speed: 2.5ms preprocess, 14.7ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 15.7ms
# Speed: 1.9ms preprocess, 15.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 14.9ms
# Speed: 1.7ms preprocess, 14.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 3 persons, 1 tv, 1 cell phone, 13.4ms
# Speed: 2.0ms preprocess, 13.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 2 cell phones, 12.6ms
# Speed: 2.1ms preprocess, 12.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 2 cell phones, 13.4ms
# Speed: 2.5ms preprocess, 13.4ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 1 cell phone, 19.3ms
# Speed: 3.1ms preprocess, 19.3ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 1 cell phone, 12.7ms
# Speed: 1.7ms preprocess, 12.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 2 cell phones, 18.7ms
# Speed: 2.3ms preprocess, 18.7ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 13.5ms
# Speed: 1.7ms preprocess, 13.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 13.8ms
# Speed: 2.1ms preprocess, 13.8ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 14.9ms
# Speed: 1.9ms preprocess, 14.9ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 12.0ms
# Speed: 3.7ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 12.2ms
# Speed: 3.8ms preprocess, 12.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 13.3ms
# Speed: 3.0ms preprocess, 13.3ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 14.1ms
# Speed: 1.7ms preprocess, 14.1ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 14.4ms
# Speed: 2.4ms preprocess, 14.4ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 13.2ms
# Speed: 1.8ms preprocess, 13.2ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 1 cell phone, 12.0ms
# Speed: 1.6ms preprocess, 12.0ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 14.0ms
# Speed: 1.8ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 1 cell phone, 13.6ms
# Speed: 1.6ms preprocess, 13.6ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 1 cell phone, 13.3ms
# Speed: 1.7ms preprocess, 13.3ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tv, 13.3ms
# Speed: 1.8ms preprocess, 13.3ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 sports ball, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 sports ball, 15.1ms
# Speed: 3.4ms preprocess, 15.1ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 sports ball, 13.4ms
# Speed: 2.5ms preprocess, 13.4ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 sports ball, 12.4ms
# Speed: 1.8ms preprocess, 12.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tie, 1 sports ball, 13.0ms
# Speed: 2.8ms preprocess, 13.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 sports ball, 14.9ms
# Speed: 1.9ms preprocess, 14.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 sports ball, 13.1ms
# Speed: 1.8ms preprocess, 13.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 tie, 13.3ms
# Speed: 1.7ms preprocess, 13.3ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 2 sports balls, 13.8ms
# Speed: 1.7ms preprocess, 13.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 1 sports ball, 13.5ms
# Speed: 1.7ms preprocess, 13.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 15.6ms
# Speed: 1.7ms preprocess, 15.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 12.4ms
# Speed: 3.5ms preprocess, 12.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 12.1ms
# Speed: 3.2ms preprocess, 12.1ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 19.4ms
# Speed: 1.6ms preprocess, 19.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 14.7ms
# Speed: 1.8ms preprocess, 14.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 13.7ms
# Speed: 1.9ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 13.3ms
# Speed: 2.0ms preprocess, 13.3ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 17.6ms
# Speed: 1.6ms preprocess, 17.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 13.5ms
# Speed: 1.6ms preprocess, 13.5ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 12.6ms
# Speed: 1.4ms preprocess, 12.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 11.4ms
# Speed: 1.7ms preprocess, 11.4ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 11.9ms
# Speed: 1.5ms preprocess, 11.9ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 12.3ms
# Speed: 1.9ms preprocess, 12.3ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 13.6ms
# Speed: 2.5ms preprocess, 13.6ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 13.0ms
# Speed: 2.6ms preprocess, 13.0ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 16.2ms
# Speed: 2.5ms preprocess, 16.2ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 14.0ms
# Speed: 2.5ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 14.6ms
# Speed: 4.5ms preprocess, 14.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 14.6ms
# Speed: 1.7ms preprocess, 14.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 13.5ms
# Speed: 1.9ms preprocess, 13.5ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 12.6ms
# Speed: 2.8ms preprocess, 12.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 17.5ms
# Speed: 1.6ms preprocess, 17.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 persons, 12.4ms
# Speed: 1.7ms preprocess, 12.4ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
